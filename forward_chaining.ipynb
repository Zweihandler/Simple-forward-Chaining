# %%
fakta = {
    'A' : True,
    'E' : True,
    'G' : False,
    'F' : False,
    'H' : False,
    'D' : False,
    'J' : False,
    'K' : False,
    'B' : False,
    'C' : False,
    'I' : False
    }

rule = {
    'R1' : False,
    'R2' : False,
    'R3' : False,
    'R4' : False,
    'R5' : False,
    'R6' : False,
    'R7' : False,
    'R8' : False,
    'R9' : False,
    'R10' : False
    }

rules_fired = []
i=0
perubahan = True
while perubahan == True:
  perubahan = False
  i+=1
  print('iterasi ke -',i)
  #Rule 1
  if rule['R1'] is False:
    if fakta['A'] is True and fakta['B'] is True :
      fakta['C'] = True
      perubahan = True
      rules_fired.append('R1')
      rule['R1'] = True
  print('Rule ke-1 :', rule['R1'])

   #Rule 2
  if rule['R2'] is False:
    if fakta['C'] is True :
      fakta['D'] = True
      perubahan = True
      rules_fired.append('R2')
      rule['R2'] = True
  print('Rule ke-2 :', rule['R2'])


  #Rule 3
  if rule['R3'] is False:
    if fakta['A'] is True and fakta['E'] is True :
      fakta['F'] = True
      perubahan = True
      rules_fired.append('R3')
      rule['R3'] = True
  print('Rule ke-3 :', rule['R3'])

  #Rule 4
  if rule['R4'] is False:
    if fakta['A'] is True:
      fakta['G'] = True
      perubahan = True
      rules_fired.append('R4')
      rule['R4'] = True
  print('Rule ke-4 :', rule['R4'])

  #Rule 5
  if rule['R5'] is False:
    if fakta['F'] is True and fakta['G'] is True:
      fakta['D'] = True
      perubahan = True
      rules_fired.append('R5')
      rule['R5'] = True
  print('Rule ke-5 :', rule['R5'])

  #Rule 6
  if rule['R5'] is False:
    if fakta['G'] is True and fakta['E'] is True:
      fakta['H'] = True
      perubahan = True
      rules_fired.append('R6')
      rule['R6'] = True
  print('Rule ke-6 :', rule['R6'])

  #Rule 7
  if rule['R5'] is False:
    if fakta['C'] is True and fakta['H'] is True:
      fakta['I'] = True
      perubahan = True
      rules_fired.append('R7')
      rule['R7'] = True
  print('Rule ke-7 :', rule['R7'])

  #Rule 8
  if rule['R5'] is False:
    if fakta['I'] is True and fakta['A'] is True:
      fakta['J'] = True
      perubahan = True
      rules_fired.append('R8')
      rule['R8'] = True
  print('Rule ke-8 :', rule['R8'])

  #Rule 9
  if rule['R5'] is False:
    if fakta['G'] is True :
      fakta['J'] = True
      perubahan = True
      rules_fired.append('R9')
      rule['R9'] = True
  print('Rule ke-9 :', rule['R9'])

  #Rule 10
  if rule['R5'] is False:
    if fakta['J'] is True :
      fakta['K'] = True
      perubahan = True
      rules_fired.append('R10')
      rule['R10'] = True
  print('Rule ke-10 :', rule['R10'])

  print(rules_fired)
  print("Kesimpulan K : ", fakta['K'])
# Out:
# iterasi ke - 1
# Rule ke-1 : False
# Rule ke-2 : False
# Rule ke-3 : True
# Rule ke-4 : True
# Rule ke-5 : True
# Rule ke-6 : False
# Rule ke-7 : False
# Rule ke-8 : False
# Rule ke-9 : False
# Rule ke-10 : False
# ['R3', 'R4', 'R5']
# Kesimpulan K :  False
# iterasi ke - 2
# Rule ke-1 : False
# Rule ke-2 : False
# Rule ke-3 : True
# Rule ke-4 : True
# Rule ke-5 : True
# Rule ke-6 : False
# Rule ke-7 : False
# Rule ke-8 : False
# Rule ke-9 : False
# Rule ke-10 : False
# ['R3', 'R4', 'R5']
# Kesimpulan K :  False
